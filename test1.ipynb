# %%
x = 3
print(x)
# Out:
# 3

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/"
# Out:
# drive  sample_data

# %%
# !pip3 install torch==1.2.0
# Out:
# ...
#      |████████████████████████████████| 748.9MB 18kB/s
# ...
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.2.0 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
# ...

# %%
# !pip3 install tqdm==4.46.1
# Out:
# ...
#      |████████████████████████████████| 71kB 6.2MB/s
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
# !pip3 install nltk==3.4.5
# Out:
# ...
#      |████████████████████████████████| 1.5MB 7.6MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449908 sha256=08c0cd44c41c87ea68bce6ba1110ec1d7c79a391276fd3702f634d11814940a4
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# ...
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...

# %%
# !pip3 install numpy==1.16.5

# %%
# !pip install scikit-learn==0.22.1
# Out:
# ...
#      |████████████████████████████████| 7.1MB 8.7MB/s
# ...
# ERROR: umap-learn 0.4.6 has requirement numpy>=1.17, but you'll have numpy 1.16.5 which is incompatible.
# ...
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ...

# %%
# !python3 "/content/drive/My Drive/cc2vec4NN/bfp_cc2ftr.py" -train -train_data "/content/drive/My Drive/cc2vec4NN/data/train.pkl" -test_data "/content/drive/My Drive/cc2vec4NN/data/test.pkl" -dictionary_data "/content/drive/My Drive/cc2vec4NN/data/dict.pkl"
# Out:
# python3: can't open file '/content/drive/My Drive/cc2vec4NN/bfp_cc2ftr.py': [Errno 2] No such file or directory

# %%
# !python3 "/Volumes/GoogleDrive/My Drive/cc2vec4NN/bfp_cc2ftr.py"
# Out:
# python3: can't open file '/Volumes/GoogleDrive/My Drive/cc2vec4NN/bfp_cc2ftr.py': [Errno 2] No such file or directory
